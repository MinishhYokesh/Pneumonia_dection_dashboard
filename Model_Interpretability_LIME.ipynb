# %%
import os
import tensorflow as tf
import numpy as np
import PIL
import matplotlib.pyplot as plt
from keras.applications.imagenet_utils import decode_predictions

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.preprocessing import image
from keras.models import load_model
import lime
from lime import lime_image
from skimage.segmentation import mark_boundaries

# %%
from keras.models import load_model 

# Load the pre-trained VGG16 model
model = load_model('C:/Users/snega/Downloads/VGG16_model (1).h5')

# %%
import numpy as np

# %%
# Function to generate LIME explanations for an image
def generate_lime_explanation(img_path, model, num_features=8):
    explainer = lime_image.LimeImageExplainer()
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    explanation = explainer.explain_instance(img_array, model.predict, top_labels=1, hide_color=0, num_features=num_features)
    temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=num_features, hide_rest=True)
   # Then you can use mark_boundaries like this:
    plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
    plt.show()
    temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=5, hide_rest=False)
    plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
    temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=False, num_features=1000, hide_rest=False, min_weight=0.1)
    plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
    
    # Path to an example image
    img_path = 'C:/Users/snega/OneDrive/Desktop/person1_virus_12.jpeg'

# Generate LIME explanation
generate_lime_explanation(img_path, model)
# Out:
# ...
# 1/1 [==============================] - 1s 733ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Function to generate LIME explanations for an image
def generate_lime_explanation(img_path, model, num_features=8):
    explainer = lime_image.LimeImageExplainer()
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    explanation = explainer.explain_instance(img_array, model.predict, top_labels=1, hide_color=0, num_features=num_features)
    temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=num_features, hide_rest=True)
   # Then you can use mark_boundaries like this:
    plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
    plt.show()
    temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=True, num_features=5, hide_rest=False)
    plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
    temp, mask = explanation.get_image_and_mask(explanation.top_labels[0], positive_only=False, num_features=1000, hide_rest=False, min_weight=0.1)
    plt.imshow(mark_boundaries(temp / 2 + 0.5, mask))
    
    # Path to an example image
    img_path = 'C:/Users/snega/OneDrive/Desktop/person80_bacteria_391.jpeg'

# Generate LIME explanation
generate_lime_explanation(img_path, model)
# Out:
# ...
# 1/1 [==============================] - 1s 792ms/step
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
